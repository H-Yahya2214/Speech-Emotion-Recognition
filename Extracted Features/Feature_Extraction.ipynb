# %%
pip install numpy librosa tqdm
# Out:
# Requirement already satisfied: numpy in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (2.1.2)
# Requirement already satisfied: librosa in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (0.11.0)
# Requirement already satisfied: tqdm in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (4.67.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from librosa) (0.61.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from librosa) (1.14.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from librosa) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from librosa) (4.13.2)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: colorama in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: packaging in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from lazy_loader>=0.1->librosa) (24.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from numba>=0.51.0->librosa) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\n\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Imports**

# %%
import librosa
import numpy as np
import pandas as pd
import os
from tqdm import tqdm

# %% [markdown]
# **Feature Extraction & Labelling**

# %%
def extract_mfcc_from_folder(audio_folder, label, n_mfcc=13, save_folder='mfcc_features'):
    os.makedirs(save_folder, exist_ok=True)
    mfcc_features = []
    mfcc_labels = []
    mfcc_filenames = []

    audio_files = [f for f in os.listdir(audio_folder) if f.endswith('.wav')]

    for idx, filename in tqdm(enumerate(audio_files), total=len(audio_files)):
        file_path = os.path.join(audio_folder, filename)
        try:
            y, sr = librosa.load(file_path, sr=None)


            mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
            delta = librosa.feature.delta(mfcc)
            delta2 = librosa.feature.delta(mfcc, order=2)

            combined = np.vstack([mfcc, delta, delta2])
            combined_mean = np.mean(combined.T, axis=0)

            mfcc_features.append(combined_mean)
            mfcc_labels.append(label)
            mfcc_filenames.append(filename)

            # np.save(os.path.join(save_folder, f"{label}_{idx}.npy"), combined_mean)

        except Exception as e:
            print(f"Error with file {filename}: {e}")

    return np.array(mfcc_features), np.array(mfcc_labels), mfcc_filenames

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **`Check if the path has the files ot not `**

# %%
path = r"C:\Users\N\Desktop\Haneen\semester_6\machine\Neutral_segmented-20250528T193702Z-1-001\Neutral_segmented" #change it to your own unzip folder path
print(os.listdir(path))

# %% [markdown]
# **Run The Function**

# %%
mfcc_features_N, mfcc_labels_N, mfcc_filenames_N = extract_mfcc_from_folder(
    audio_folder=r"C:\Users\N\Desktop\Haneen\semester_6\machine\Neutral_segmented-20250528T193702Z-1-001\Neutral_segmented",#change it to your own unzip folder path
    label="Neutral")#change el label to your emotion name
# Out:
# ['neutral_aehhs_2492.wav', 'neutral_aehhs_2496.wav', 'neutral_aehhs_2497.wav', 'neutral_aehhs_2498.wav', 'neutral_aehhs_2501.wav', 'neutral_aehhs_2502.wav', 'neutral_aehhs_2503.wav', 'neutral_aehhs_2504.wav', 'neutral_aehhs_2510.wav', 'neutral_aehhs_2512.wav', 'neutral_aehhs_2517.wav', 'neutral_aehhs_2519.wav', 'neutral_aehhs_2520.wav', 'neutral_aehhs_2521.wav', 'neutral_aehhs_2522.wav', 'neutral_aehhs_2523.wav', 'neutral_aehhs_2525.wav', 'neutral_aehhs_2526.wav', 'neutral_aehhs_2527.wav', 'neutral_aehhs_2528.wav', 'neutral_aehhs_2530.wav', 'neutral_aehhs_2531.wav', 'neutral_aehhs_2532.wav', 'neutral_aehhs_2533.wav', 'neutral_aehhs_2534.wav', 'neutral_aehhs_2535.wav', 'neutral_aehhs_2536.wav', 'neutral_aehhs_2537.wav', 'neutral_aehhs_2538.wav', 'neutral_aehhs_2539.wav', 'neutral_aehhs_2540.wav', 'neutral_aehhs_2541.wav', 'neutral_aehhs_2542.wav', 'neutral_aehhs_2543.wav', 'neutral_aehhs_2544.wav', 'neutral_aehhs_2545.wav', 'neutral_aehhs_2546.wav', 'neutral_aehhs_2547.wav', 'neutral_aehhs_2548.wav', 'neutral_aehhs_2549.wav', 'neutral_aehhs_2550.wav', 'neutral_aehhs_2551.wav', 'neutral_aehhs_2552.wav', 'neutral_aehhs_2553.wav', 'neutral_aehhs_2554.wav', 'neutral_aehhs_2555.wav', 'neutral_aehhs_2556.wav', 'neutral_aehhs_2557.wav', 'neutral_aehhs_2558.wav', 'neutral_aehhs_2559.wav', 'neutral_aehhs_2560.wav', 'ne
# 100%|██████████████████████████████████████████████████████████████████████████████| 5377/5377 [04:42<00:00, 19.03it/s]

# %% [markdown]
# **Make DataFrame**

# %%
df_N = pd.DataFrame(mfcc_features_N)
df_N['Label'] = mfcc_labels_N
df_N['File_Name']= mfcc_filenames_N
df_N
# Out:
#                0           1          2          3          4          5  \
# 0    -287.913910  137.617432 -48.041115  38.547523 -30.853277  14.626295
# 1    -298.555847  156.171265 -44.378727  45.230450 -20.420759  15.900339
# 2    -290.951080  153.542328 -45.234261  52.115536 -17.793053  22.480532
# 3    -247.839432  140.404282 -46.182117  54.252762 -36.094250  26.255520
# 4    -263.575897  152.486343 -47.668419  43.964325 -25.803938  24.279560
# ...          ...         ...        ...        ...        ...        ...
# 5372 -498.436279  159.237000   7.903052  20.321167  25.864687  -1.748588
# 5373 -486.132080  170.607025 -13.703200  15.693749  30.111231  -6.446225
# 5374 -486.100220  169.614944   1.905995  19.538179  34.465797  -2.659995
# 5375 -561.171631  101.968582  12.137526  27.572105  35.925968   7.706303
# 5376 -602.336914  103.244476  18.780016  33.813541  22.328867  12.295284
#
#               6          7         8          9  ...        30        31  \
# 0    -19.773479  10.971231  2.434737  -2.971322  ... -0.072514 -0.007822
# 1     -8.539274   6.644521  6.259509   5.089580  ...  0.024012 -0.025456
# 2     -0.441563  10.776849  7.421404  -0.233248  ...  0.039484 -0.026120
# 3     -7.008230  11.256819  0.517748   2.440896  ... -0.018490 -0.019183
# 4     -4.939576  11.105044  2.900494   0.552982  ...  0.023680 -0.007798
# ...         ...        ...       ...        ...  ...       ...       ...
# 5372  -7.840082 -10.808754 -7.788122   3.985581  ... -0.027343  0.039525
# 5373 -10.353929  -8.388937 -7.234899   9.532722  ... -0.063137  0.071231
# 5374 -14.332887 -11.590310 -5.092456   4.568852  ... -0.173831  0.020889
# 5375  -3.144443  -1.490591  3.301049   8.773347  ... -0.091937 -0.002488
# 5376  13.918312  -1.240842 -0.808722  11.449541  ... -0.017305 -0.020223
#
#             32        33        34        35        36        37        38  \
# 0    -0.056774 -0.032238 -0.000300 -0.042035 -0.024750  0.041571  0.029707
# 1     0.003031 -0.026426 -0.030050 -0.025796 -0.005405  0.024771 -0.031764
# 2     0.011511 -0.034229 -0.003729 -0.004957 -0.017778  0.010978 -0.033453
# 3     0.011821  0.032661  0.002949 -0.007409 -0.012526  0.019094  0.001497
# 4    -0.011303 -0.019882 -0.024838 -0.013442 -0.022744 -0.016016  0.003047
# ...        ...       ...       ...       ...       ...       ...       ...
# 5372  0.013109  0.090988  0.085414 -0.018278 -0.004096  0.030486  0.016958
# 5373  0.022671  0.023750  0.079690  0.020236 -0.025677 -0.016374 -0.003171
# 5374  0.080085  0.031625  0.009646 -0.029498 -0.040934 -0.000679  0.007721
# 5375  0.000100 -0.030865  0.007337  0.031579  0.013130  0.019702  0.016550
# 5376  0.000314 -0.004741  0.006986  0.006321 -0.017493 -0.013747  0.002418
#
#         Label
# 0     Neutral
# 1     Neutral
# 2     Neutral
# 3     Neutral
# 4     Neutral
# ...       ...
# 5372  Neutral
# 5373  Neutral
# 5374  Neutral
# 5375  Neutral
# 5376  Neutral
#
# [5377 rows x 40 columns]

# %% [markdown]
# **Save the csv file**

# %%
output_csv = "SER_N.csv" #change the name of the csv _emotion first char
df_N.to_csv(output_csv, index=False, encoding='utf-8')
print(f"CSV saved to: {output_csv}")
#download the csv that in jupyter and upload it on our Machine Learning Project on drive
